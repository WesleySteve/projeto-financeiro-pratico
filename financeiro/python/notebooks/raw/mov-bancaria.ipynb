# %% [markdown]
# # Analise arquivos raw movimentacao-bancaria.csv

# %%
import os
import pandas as pd
from pandasql import sqldf

pysqldf = lambda q: sqldf(q, globals())

# %%
BASE_DIR = os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath('.')))))
DATA_DIR = os.path.join(BASE_DIR, 'data')
RAW_DIR =  os.path.join(DATA_DIR, 'raw')

# %%
df = pd.read_csv(os.path.join(RAW_DIR, 'movimentacoes_bancarias.csv'), sep=';')
df.shape
# Out:
# (1015, 8)

# %% [markdown]
# ## Analise exploratória

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1015 entries, 0 to 1014
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_movimento    1015 non-null   str
#  1   data_movimento  1015 non-null   str
#  2   tipo            994 non-null    str
#  3   categoria       995 non-null    str
#  4   descricao       995 non-null    str
#  5   valor           995 non-null    str
#  6   conta_bancaria  995 non-null    str
#  7   conciliado      995 non-null    str
# dtypes: str(8)
# memory usage: 63.6 KB

# %%
df.isna().sum()
# Out:
# id_movimento       0
# data_movimento     0
# tipo              21
# categoria         20
# descricao         20
# valor             20
# conta_bancaria    20
# conciliado        20
# dtype: int64

# %%
df.head()
# Out:
#   id_movimento data_movimento     tipo               categoria  \
# 0     MB000001     2026-05-14  Entrada                  Outros
# 1     MB000002     2026-03-15  Entrada                 Energia
# 2     MB000003     2026-03-14    Saída    Pagamento fornecedor
# 3     MB000004     2026-04-21    Saída  Recebimento de cliente
# 4     MB000005     2026-08-13  Entrada                  Outros
#
#                              descricao     valor conta_bancaria conciliado
# 0                  Outros - operação 1  11974.55        Banco B        Sim
# 1                 Energia - operação 2    329.88        Banco A        Sim
# 2                                  NaN   1004.82        Banco B        Sim
# 3  Recebimento de cliente - operação 4    945.74        Banco A        Sim
# 4                  Outros - operação 5   11992.6        Banco C        Sim

# %%
df.tail()
# Out:
#      id_movimento data_movimento     tipo        categoria  \
# 1010     MB000025     2026-06-04  Entrada           Outros
# 1011     MB000243     2026-03-21  Entrada           Outros
# 1012     MB000543     2026-06-12    Saída    Transferência
# 1013     MB000931     2026-07-29  Entrada          Energia
# 1014     MB000887     2026-03-18    Saída  Tarifa bancária
#
#                             descricao    valor conta_bancaria conciliado
# 1010             Outros - operação 25   1788.7        Banco A        Sim
# 1011            Outros - operação 243  6344.79        Banco B        Sim
# 1012    Transferência - operação 543   3313.07        Banco A        Sim
# 1013           Energia - operação 931  7136.89        Banco A        sim
# 1014   Tarifa bancária - operação 887   970.59        Banco C        Sim

# %%
df.sample(5)
# Out:
#     id_movimento data_movimento     tipo               categoria  \
# 951     MB000952     2026-08-02    Saída                  Outros
# 540     MB000541     2026-01-01    Saída  Recebimento de cliente
# 429     MB000430     2026-04-08    Saída         Tarifa bancária
# 89      MB000090     2026-07-13  Entrada                Impostos
# 689     MB000690     2026-01-28  Entrada           Transferência
#
#                                  descricao     valor conta_bancaria conciliado
# 951                  Outros - operação 952  13886.56        Banco B        Sim
# 540  Recebimento de cliente - operação 541    133.67        Banco B        Sim
# 429         Tarifa bancária - operação 430  17310.16        Banco A        Sim
# 89                  Impostos - operação 90  13077.86        Banco C        Sim
# 689           Transferência - operação 690   5003.29        Banco C        Não

# %%
df.isnull().sum()
# Out:
# id_movimento       0
# data_movimento     0
# tipo              21
# categoria         20
# descricao         20
# valor             20
# conta_bancaria    20
# conciliado        20
# dtype: int64

# %%
q = '''SELECT id_movimento
            , tipo
            , categoria
            , descricao
            , valor
            , conta_bancaria
            , conciliado
        FROM df
        WHERE tipo is null
            or categoria isnull
            or valor isnull
            or conta_bancaria isnull
            or conciliado isnull

'''
pysqldf(q)
# Out:
#    id_movimento     tipo      categoria                     descricao  \
# 0      MB000027    Saída  Transferência   Transferência - operação 27
# 1      MB000032  Entrada  Transferência   Transferência - operação 32
# 2      MB000040      NaN        Salário         Salário - operação 40
# 3      MB000046  Entrada            NaN   Transferência - operação 46
# 4      MB000063      NaN        Aluguel         Aluguel - operação 63
# ..          ...      ...            ...                           ...
# 95     MB000939  Entrada            NaN        Salário - operação 939
# 96     MB000945  Entrada  Transferência  Transferência - operação 945
# 97     MB000991    Saída       Energia         Energia - operação 991
# 98     MB000996  Entrada  Transferência  Transferência - operação 996
# 99     MB000488      NaN  Transferência  Transferência - operação 488
#
#        valor conta_bancaria conciliado
# 0    17689.4            NaN        Sim
# 1        NaN        Banco B        Sim
# 2    10389.9        Banco C        Sim
# 3   13752.17        Banco C        Sim
# 4    8909.31        Banco C        Não
# ..       ...            ...        ...
# 95  16762.92        Banco C        Sim
# 96       NaN        Banco B        Sim
# 97   7902.24        Banco B        NaN
# 98   3656.59        Banco B        NaN
# 99   4023.92        Banco B        Sim
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Tratamento de dados

# %%
df_original = df.copy()

# %%
df = df.fillna('NAO INFORMADO')

# %%
# Remove espaços antes/depois dos nomes
df.columns = df.columns.str.strip()

# %%
campos_texto = [
    "id_movimento"
    , "tipo"
    , "categoria"
    , "descricao"
    , "conta_bancaria"
    , "conciliado"
]

# %%
for campo in campos_texto:

    df[campo] = (
        df[campo]
        .astype("string")
        .str.strip()
    )

# %%
# campos datas

df['data_movimento'] = df['data_movimento'].replace('NAO INFORMADO', '1900-01-01', regex=True)
df['data_movimento'] = df['data_movimento'].replace('/', '-',  regex=True)

# %%
df['data_movimento'] = pd.to_datetime(df['data_movimento'], format='mixed')

# %%
df['valor'] = df['valor'].replace('NAO INFORMADO', 0)

# %%
df['valor'] = pd.to_numeric(df['valor'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1015 entries, 0 to 1014
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_movimento    1015 non-null   string
#  1   data_movimento  1015 non-null   datetime64[us]
#  2   tipo            1015 non-null   string
#  3   categoria       1015 non-null   string
#  4   descricao       1015 non-null   string
#  5   valor           1014 non-null   float64
#  6   conta_bancaria  1015 non-null   string
#  7   conciliado      1015 non-null   string
# dtypes: datetime64[us](1), float64(1), string(6)
# memory usage: 63.6 KB

# %%
df.head()
# Out:
#   id_movimento data_movimento     tipo               categoria  \
# 0     MB000001     2026-05-14  Entrada                  Outros
# 1     MB000002     2026-03-15  Entrada                 Energia
# 2     MB000003     2026-03-14    Saída    Pagamento fornecedor
# 3     MB000004     2026-04-21    Saída  Recebimento de cliente
# 4     MB000005     2026-08-13  Entrada                  Outros
#
#                              descricao     valor conta_bancaria conciliado
# 0                  Outros - operação 1  11974.55        Banco B        Sim
# 1                 Energia - operação 2    329.88        Banco A        Sim
# 2                        NAO INFORMADO   1004.82        Banco B        Sim
# 3  Recebimento de cliente - operação 4    945.74        Banco A        Sim
# 4                  Outros - operação 5  11992.60        Banco C        Sim

# %%
df.tail()
# Out:
#      id_movimento data_movimento     tipo        categoria  \
# 1010     MB000025     2026-06-04  Entrada           Outros
# 1011     MB000243     2026-03-21  Entrada           Outros
# 1012     MB000543     2026-06-12    Saída    Transferência
# 1013     MB000931     2026-07-29  Entrada          Energia
# 1014     MB000887     2026-03-18    Saída  Tarifa bancária
#
#                            descricao    valor conta_bancaria conciliado
# 1010            Outros - operação 25  1788.70        Banco A        Sim
# 1011           Outros - operação 243  6344.79        Banco B        Sim
# 1012    Transferência - operação 543  3313.07        Banco A        Sim
# 1013          Energia - operação 931  7136.89        Banco A        sim
# 1014  Tarifa bancária - operação 887   970.59        Banco C        Sim

# %%
df.sample(5)
# Out:
#     id_movimento data_movimento           tipo             categoria  \
# 924     MB000925     2026-03-12          Saída       Tarifa bancária
# 399     MB000400     2026-05-24  NAO INFORMADO         Transferência
# 441     MB000442     2026-02-13        Entrada  Pagamento fornecedor
# 699     MB000700     2026-05-21        Entrada               Aluguel
# 282     MB000283     2026-01-09        Entrada       Tarifa bancária
#
#                                descricao     valor conta_bancaria conciliado
# 924       Tarifa bancária - operação 925  16018.08        Banco C        Não
# 399         Transferência - operação 400   4451.82        Banco C        Sim
# 441  Pagamento fornecedor - operação 442    318.15        Banco A        Sim
# 699               Aluguel - operação 700   8100.54        Banco A        Sim
# 282       Tarifa bancária - operação 283   3272.35        Banco B        Sim

# %% [markdown]
# ## Salvando dados Movimentacoes Bancarias em Bronze

# %%
BRONZE_DIR = os.path.join(DATA_DIR, 'bronze')

# %%
df.to_csv(
    os.path.join(BRONZE_DIR, 'b_movimentacoes_bancarias.csv')
    , index=False
    , date_format="%Y-%m-%d"
)
