# %% [markdown]
# # Analise arquivo raw clientes.csv

# %%
import os
import pandas as pd
from pandasql import sqldf

pysqldf = lambda q: sqldf(q, globals())

# %%
BASE_DIR = os.path.dirname(os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath('.')))))
DATA_DIR = os.path.join(BASE_DIR, 'data')
RAW_DIR =  os.path.join(DATA_DIR, 'raw')

# %%
df = pd.read_csv(os.path.join(RAW_DIR, 'clientes.csv'), sep=';')
df.shape
# Out:
# (51, 7)

# %% [markdown]
# ## Analise exploratória

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_cliente      51 non-null     str
#  1   nome_cliente    50 non-null     str
#  2   cidade          50 non-null     str
#  3   uf              50 non-null     str
#  4   segmento        50 non-null     str
#  5   limite_credito  49 non-null     str
#  6   status          50 non-null     str
# dtypes: str(7)
# memory usage: 2.9 KB

# %%
df.isna().sum()
# Out:
# id_cliente        0
# nome_cliente      1
# cidade            1
# uf                1
# segmento          1
# limite_credito    2
# status            1
# dtype: int64

# %%
df.head()
# Out:
#   id_cliente             nome_cliente               cidade  uf      segmento  \
# 0      C0001  Comercial Presidente 01        Regente Feijó  SP        Varejo
# 1      C0002       Mercado Central 02                  NaN  SP        Varejo
# 2      C0003  Supermercado Avenida 03      Santo Anastácio  SP        Varejo
# 3      C0004       Mercado Central 04  Presidente Prudente  SP       Mercado
# 4      C0005    Supermercado União 05          pirapozinho  SP  Food Service
#
#   limite_credito status
# 0       60616.29  Ativo
# 1       55752.46  Ativo
# 2        7234.79  Ativo
# 3       58701.47  Ativo
# 4       49194.93  Ativo

# %%
df.tail()
# Out:
#    id_cliente             nome_cliente               cidade   uf  \
# 46      C0047  Supermercado Avenida 47  Presidente Prudente   SP
# 47      C0048       Comercial Oeste 48      Santo Anastácio   SP
# 48      C0049     Mercado Esperança 49  Presidente Prudente   SP
# 49      C0050      Empório Prudente 50            Rancharia  NaN
# 50      C0014         Mercado Ideal 14        Regente Feijó   SP
#
#         segmento limite_credito status
# 46        Varejo       77674.72  Ativo
# 47  Food Service       41101.88  Ativo
# 48       Mercado       33422.98  Ativo
# 49       Atacado       36725.56  Ativo
# 50       Mercado            NaN  Ativo

# %%
df.sample(5)
# Out:
#    id_cliente               nome_cliente                cidade  uf  \
# 41      C0042      Supermercado União 42       Santo Anastácio  SP
# 20      C0021          Rede Bom Preço 21           Pirapozinho  SP
# 7       C0008          Rede Bom Preço 08  Presidente Bernardes  SP
# 27      C0028  Distribuidora Nova Era 28           Pirapozinho  SP
# 47      C0048         Comercial Oeste 48       Santo Anastácio  SP
#
#         segmento limite_credito status
# 41  Food Service       69787.76  Ativo
# 20       Mercado       43214.47  Ativo
# 7        Atacado       65534.62  Ativo
# 27       Mercado       33043.54  Ativo
# 47  Food Service       41101.88  Ativo

# %%
df.isnull().sum()
# Out:
# id_cliente        0
# nome_cliente      1
# cidade            1
# uf                1
# segmento          1
# limite_credito    2
# status            1
# dtype: int64

# %%
q = '''SELECT id_cliente
                , nome_cliente
                , cidade
                , uf
                , segmento
                , status
            FROM df
        WHERE nome_cliente isnull
                or cidade isnull
                or uf isnull
                or segmento isnull
                or status isnull
    '''
print(pysqldf(q))
# Out:
#   id_cliente         nome_cliente                cidade   uf segmento status
# 0      C0002   Mercado Central 02                   NaN   SP   Varejo  Ativo
# 1      C0030                  NaN  Presidente Bernardes   SP  Atacado  Ativo
# 2      C0036    Rede Bom Preço 36   Presidente Prudente   SP      NaN    NaN
# 3      C0050  Empório Prudente 50             Rancharia  NaN  Atacado  Ativo

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_cliente      51 non-null     str
#  1   nome_cliente    50 non-null     str
#  2   cidade          50 non-null     str
#  3   uf              50 non-null     str
#  4   segmento        50 non-null     str
#  5   limite_credito  49 non-null     str
#  6   status          50 non-null     str
# dtypes: str(7)
# memory usage: 2.9 KB

# %% [markdown]
# ## Tratamento de dados

# %%
df_original = df.copy()

# %%
df = df.fillna('NAO INFORMADO')

# %%
df[['limite_credito']] = df[['limite_credito']].replace('NAO INFORMADO', 0)

# %%
df['limite_credito'] = pd.to_numeric(df['limite_credito'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_cliente      51 non-null     str
#  1   nome_cliente    51 non-null     str
#  2   cidade          51 non-null     str
#  3   uf              51 non-null     str
#  4   segmento        51 non-null     str
#  5   limite_credito  50 non-null     float64
#  6   status          51 non-null     str
# dtypes: float64(1), str(6)
# memory usage: 2.9 KB

# %%
df.sample(10)
# Out:
#    id_cliente               nome_cliente                cidade  uf  \
# 40      C0041         Mercado Central 41         Regente Feijó  SP
# 14      C0015         Comercial Oeste 15             Rancharia  SP
# 16      C0017       Supermercado Real 17  Presidente Bernardes  SP
# 29      C0030              NAO INFORMADO  Presidente Bernardes  SP
# 45      C0046         Mercado Central 46         Regente Feijó  SP
# 28      C0029       Mercado São Lucas 29   Presidente Prudente  SP
# 23      C0024        Casa das Compras 24          Martinópolis  SP
# 50      C0014           Mercado Ideal 14         Regente Feijó  SP
# 27      C0028  Distribuidora Nova Era 28           Pirapozinho  SP
# 15      C0016         Mercado Central 16  Presidente Bernardes  SP
#
#         segmento  limite_credito status
# 40        Varejo        54423.71  Ativo
# 14  Food Service        25246.09  Ativo
# 16  Food Service        25080.57  Ativo
# 29       Atacado        22958.92  Ativo
# 45  Food Service        65601.67  Ativo
# 28       Atacado        41645.43  Ativo
# 23        Varejo        56021.26  Ativo
# 50       Mercado            0.00  Ativo
# 27       Mercado        33043.54  Ativo
# 15        Varejo        22178.61  Ativo

# %% [markdown]
# ## Salvando dados de clientes em Bronze

# %%
BRONZE_DIR = os.path.join(DATA_DIR, 'bronze')

# %%
df.to_csv(os.path.join(BRONZE_DIR, 'b_clientes.csv'), index=False)
